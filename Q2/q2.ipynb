# %%
def main():
    import matplotlib.pyplot as plt

    f = open('q2.csv')
    data = csv.reader(f)
    header = next(data)
    result_100times = []
    result_1000times = []
    result_10000times = []
    result_100000times = []
    for row in data:
        if row[0] != '':
            result_100times.append(int(row[0]))
        if row[1] != '':
            result_1000times.append(int(row[1]))
        if row[2] != '':
            result_10000times.append(int(row[2]))
        if row[3] != '':
            result_100000times.append(int(row[3]))
        
    data_list = [result_100times,result_1000times,result_10000times,result_100000times]
    fig, axs = plt.subplots(2, 2, figsize=(10, 8))

    titles = ['100 times', '1000 times', '10000 times', '100000 times']
    for i, ax in enumerate(axs.flat):
        ax.hist(data_list[i], bins=11)
        ax.set_title(titles[i])
        ax.set_xlabel('Values')
        ax.set_ylabel('Frequency')
    
    plt.tight_layout()
    plt.show()

if __name__ == '__main__':
    main()
